# %%
import json
import os

def is_valid_json(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            json.load(file)
        return True
    except json.JSONDecodeError:
        return False

def fix_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    # Check and remove the problematic lines if they exist
    if lines[0].strip() == '```json':
        lines = lines[1:]  # Remove the first line
    if lines[-1].strip() == '```':
        lines = lines[:-1]  # Remove the last line

    # Try to join back the lines and parse as JSON
    try:
        json_data = json.loads(''.join(lines))
        # If successful, write back the corrected JSON
        with open(file_path, 'w', encoding='utf-8') as file:
            json.dump(json_data, file, indent=4)
        print(f"Fixed and saved valid JSON to {file_path}")
    except json.JSONDecodeError as e:
        print(f"Error fixing {file_path}: {e}")

def process_directory(directory_path):
    for filename in os.listdir(directory_path):
        if filename.endswith('.json'):
            file_path = os.path.join(directory_path, filename)
            if not is_valid_json(file_path):
                print(f"Invalid JSON detected: {filename}, attempting to fix...")
                fix_json_file(file_path)
            else:
                print(f"{filename} is a valid JSON file.")

# Replace 'your_directory_path' with the path to your directory containing JSON files
directory_path = 'leaflet_jsons'
process_directory(directory_path)
# Out:
# Invalid JSON detected: 13831.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13831.json
# Invalid JSON detected: 28267.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28267.json
# 19164.json is a valid JSON file.
# Invalid JSON detected: 23719.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23719.json
# Invalid JSON detected: 16611.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16611.json
# Invalid JSON detected: 15137.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15137.json
# 18784.json is a valid JSON file.
# 8409.json is a valid JSON file.
# 30677.json is a valid JSON file.
# 26053.json is a valid JSON file.
# Invalid JSON detected: 29684.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29684.json
# Invalid JSON detected: 33345.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33345.json
# Invalid JSON detected: 9956.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9956.json
# 33130.json is a valid JSON file.
# Invalid JSON detected: 2985.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/2985.json
# 32143.json is a valid JSON file.
# Invalid JSON detected: 35129.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/35129.json
# 18450.json is a valid JSON file.
# 12734.json is a valid JSON file.
# Invalid JSON detected: 31111.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31111.json
# 11175.json is a valid JSON file.
# 32080.json is a valid JSON file.
# 38845.json is a valid JSON file.
# Invalid JSON detected: 23046.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23046.json
# Invalid JSON detected: 18319.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18319.json
# 24652.json is a valid JSON file.
# Invalid JSON detected: 14612.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/14612.json
# Invalid JSON detected: 7582.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7582.json
# Invalid JSON detected: 9300.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9300.json
# Invalid JSON detected: 31465.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31465.json
# Invalid JSON detected: 31669.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31669.json
# Invalid JSON detected: 10015.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10015.json
# Invalid JSON detected: 34237.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34237.json
# Invalid JSON detected: 26008.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26008.json
# Invalid JSON detected: 7290.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7290.json
# 11670.json is a valid JSON file.
# Invalid JSON detected: 27279.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27279.json
# 33856.json is a valid JSON file.
# Invalid JSON detected: 7588.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7588.json
# Invalid JSON detected: 16052.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16052.json
# Invalid JSON detected: 13818.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13818.json
# 31244.json is a valid JSON file.
# Invalid JSON detected: 23113.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23113.json
# 15860.json is a valid JSON file.
# Invalid JSON detected: 34095.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34095.json
# Invalid JSON detected: 10380.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10380.json
# 16744.json is a valid JSON file.
# 20549.json is a valid JSON file.
# 12428.json is a valid JSON file.
# Invalid JSON detected: 7972.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7972.json
# 10596.json is a valid JSON file.
# 25683.json is a valid JSON file.
# Invalid JSON detected: 19761.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19761.json
# Invalid JSON detected: 29746.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29746.json
# Invalid JSON detected: 12842.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12842.json
# Invalid JSON detected: 11236.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11236.json
# 17805.json is a valid JSON file.
# 35533.json is a valid JSON file.
# Invalid JSON detected: 30202.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30202.json
# Invalid JSON detected: 20779.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20779.json
# 11304.json is a valid JSON file.
# 34802.json is a valid JSON file.
# Invalid JSON detected: 13572.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13572.json
# 17847.json is a valid JSON file.
# Invalid JSON detected: 5258.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5258.json
# Invalid JSON detected: 13583.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13583.json
# Invalid JSON detected: 13185.json, attempting to fix...
# Error fixing leaflet_jsons/13185.json: Invalid control character at: line 87 column 113 (char 5701)
# Invalid JSON detected: 20821.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20821.json
# Invalid JSON detected: 20827.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20827.json
# 5266.json is a valid JSON file.
# Invalid JSON detected: 26314.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26314.json
# Invalid JSON detected: 19153.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19153.json
# 26105.json is a valid JSON file.
# Invalid JSON detected: 22951.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22951.json
# Invalid JSON detected: 8666.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8666.json
# Invalid JSON detected: 3740.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3740.json
# Invalid JSON detected: 32532.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32532.json
# 4346.json is a valid JSON file.
# Invalid JSON detected: 23744.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23744.json
# Invalid JSON detected: 22791.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22791.json
# 19144.json is a valid JSON file.
# 4399.json is a valid JSON file.
# Invalid JSON detected: 16767.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16767.json
# 29398.json is a valid JSON file.
# 33724.json is a valid JSON file.
# Invalid JSON detected: 12161.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12161.json
# Invalid JSON detected: 16331.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16331.json
# 37446.json is a valid JSON file.
# Invalid JSON detected: 29085.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29085.json
# Invalid JSON detected: 19791.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19791.json
# 15289.json is a valid JSON file.
# Invalid JSON detected: 37569.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37569.json
# 10043.json is a valid JSON file.
# Invalid JSON detected: 22608.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22608.json
# Invalid JSON detected: 20813.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20813.json
# 33051.json is a valid JSON file.
# Invalid JSON detected: 17829.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17829.json
# Invalid JSON detected: 23007.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23007.json
# Invalid JSON detected: 23791.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23791.json
# 27946.json is a valid JSON file.
# 29128.json is a valid JSON file.
# Invalid JSON detected: 7577.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7577.json
# Invalid JSON detected: 8245.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8245.json
# Invalid JSON detected: 38775.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/38775.json
# Invalid JSON detected: 34983.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34983.json
# Invalid JSON detected: 29155.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29155.json
# Invalid JSON detected: 9539.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9539.json
# Invalid JSON detected: 8634.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8634.json
# Invalid JSON detected: 34526.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34526.json
# Invalid JSON detected: 5166.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5166.json
# 10974.json is a valid JSON file.
# 7894.json is a valid JSON file.
# Invalid JSON detected: 21532.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21532.json
# 24278.json is a valid JSON file.
# Invalid JSON detected: 27486.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27486.json
# Invalid JSON detected: 9139.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9139.json
# Invalid JSON detected: 5369.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5369.json
# 38743.json is a valid JSON file.
# Invalid JSON detected: 11570.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11570.json
# Invalid JSON detected: 34416.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34416.json
# 5287.json is a valid JSON file.
# Invalid JSON detected: 31737.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31737.json
# 4870.json is a valid JSON file.
# Invalid JSON detected: 14636.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/14636.json
# 24938.json is a valid JSON file.
# 18491.json is a valid JSON file.
# 34382.json is a valid JSON file.
# Invalid JSON detected: 29668.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29668.json
# 23118.json is a valid JSON file.
# Invalid JSON detected: 23687.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23687.json
# 4261.json is a valid JSON file.
# Invalid JSON detected: 15659.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15659.json
# Invalid JSON detected: 20501.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20501.json
# Invalid JSON detected: 13246.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13246.json
# Invalid JSON detected: 24710.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24710.json
# 15207.json is a valid JSON file.
# Invalid JSON detected: 15157.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15157.json
# Invalid JSON detected: 21529.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21529.json
# Invalid JSON detected: 27056.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27056.json
# 24857.json is a valid JSON file.
# Invalid JSON detected: 24222.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24222.json
# Invalid JSON detected: 32737.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32737.json
# Invalid JSON detected: 10207.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10207.json
# 33357.json is a valid JSON file.
# Invalid JSON detected: 29436.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29436.json
# 37634.json is a valid JSON file.
# 22907.json is a valid JSON file.
# Invalid JSON detected: 11828.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11828.json
# Invalid JSON detected: 37123.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37123.json
# 15321.json is a valid JSON file.
# Invalid JSON detected: 8794.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8794.json
# Invalid JSON detected: 9505.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9505.json
# 18856.json is a valid JSON file.
# 26610.json is a valid JSON file.
# Invalid JSON detected: 5977.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5977.json
# Invalid JSON detected: 32599.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32599.json
# 4151.json is a valid JSON file.
# Invalid JSON detected: 22857.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22857.json
# 12989.json is a valid JSON file.
# Invalid JSON detected: 23988.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23988.json
# Invalid JSON detected: 34987.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34987.json
# Invalid JSON detected: 8350.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8350.json
# Invalid JSON detected: 10788.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10788.json
# 22235.json is a valid JSON file.
# Invalid JSON detected: 22123.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22123.json
# 17385.json is a valid JSON file.
# 29454.json is a valid JSON file.
# Invalid JSON detected: 4495.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4495.json
# Invalid JSON detected: 18792.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18792.json
# 18503.json is a valid JSON file.
# Invalid JSON detected: 15848.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15848.json
# Invalid JSON detected: 8129.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8129.json
# Invalid JSON detected: 24389.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24389.json
# 22255.json is a valid JSON file.
# Invalid JSON detected: 25229.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/25229.json
# Invalid JSON detected: 18808.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18808.json
# Invalid JSON detected: 2922.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/2922.json
# 38690.json is a valid JSON file.
# Invalid JSON detected: 35106.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/35106.json
# Invalid JSON detected: 5910.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5910.json
# Invalid JSON detected: 12866.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12866.json
# 37323.json is a valid JSON file.
# 37754.json is a valid JSON file.
# Invalid JSON detected: 27270.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27270.json
# Invalid JSON detected: 37820.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37820.json
# Invalid JSON detected: 6408.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6408.json
# Invalid JSON detected: 7357.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7357.json
# Invalid JSON detected: 4043.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4043.json
# Invalid JSON detected: 30419.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30419.json
# 12597.json is a valid JSON file.
# Invalid JSON detected: 9072.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9072.json
# 19835.json is a valid JSON file.
# Invalid JSON detected: 25041.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/25041.json
# Invalid JSON detected: 3522.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3522.json
# Invalid JSON detected: 13128.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13128.json
# 22490.json is a valid JSON file.
# 10336.json is a valid JSON file.
# 25769.json is a valid JSON file.
# Invalid JSON detected: 22746.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22746.json
# 33685.json is a valid JSON file.
# Invalid JSON detected: 4671.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4671.json
# 10477.json is a valid JSON file.
# 25101.json is a valid JSON file.
# 21761.json is a valid JSON file.
# Invalid JSON detected: 11206.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11206.json
# 24346.json is a valid JSON file.
# Invalid JSON detected: 24401.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24401.json
# 3296.json is a valid JSON file.
# 17675.json is a valid JSON file.
# 30937.json is a valid JSON file.
# Invalid JSON detected: 3028.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3028.json
# Invalid JSON detected: 20789.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20789.json
# Invalid JSON detected: 29777.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29777.json
# 21385.json is a valid JSON file.
# 12980.json is a valid JSON file.
# Invalid JSON detected: 22495.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22495.json
# Invalid JSON detected: 22046.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22046.json
# 4116.json is a valid JSON file.
# Invalid JSON detected: 18996.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18996.json
# Invalid JSON detected: 9271.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9271.json
# Invalid JSON detected: 8702.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8702.json
# Invalid JSON detected: 11662.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11662.json
# Invalid JSON detected: 13727.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13727.json
# 25585.json is a valid JSON file.
# Invalid JSON detected: 37885.json, attempting to fix...
# Error fixing leaflet_jsons/37885.json: Expecting ',' delimiter: line 40 column 9 (char 2283)
# Invalid JSON detected: 39080.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/39080.json
# Invalid JSON detected: 27682.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27682.json
# 10811.json is a valid JSON file.
# 8844.json is a valid JSON file.
# 25639.json is a valid JSON file.
# 25888.json is a valid JSON file.
# Invalid JSON detected: 5990.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5990.json
# Invalid JSON detected: 28207.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28207.json
# 27574.json is a valid JSON file.
# Invalid JSON detected: 28722.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28722.json
# Invalid JSON detected: 32463.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32463.json
# Invalid JSON detected: 28407.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28407.json
# Invalid JSON detected: 23134.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23134.json
# 34683.json is a valid JSON file.
# 24876.json is a valid JSON file.
# 20805.json is a valid JSON file.
# Invalid JSON detected: 5169.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5169.json
# Invalid JSON detected: 30829.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30829.json
# 28875.json is a valid JSON file.
# 12497.json is a valid JSON file.
# Invalid JSON detected: 7641.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7641.json
# Invalid JSON detected: 19931.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19931.json
# Invalid JSON detected: 30764.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30764.json
# Invalid JSON detected: 19371.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19371.json
# Invalid JSON detected: 5159.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5159.json
# Invalid JSON detected: 28626.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28626.json
# Invalid JSON detected: 10031.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10031.json
# Invalid JSON detected: 16709.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16709.json
# Invalid JSON detected: 24892.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24892.json
# Invalid JSON detected: 4674.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4674.json
# Invalid JSON detected: 34553.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34553.json
# Invalid JSON detected: 19646.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19646.json
# Invalid JSON detected: 29263.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29263.json
# Invalid JSON detected: 23069.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23069.json
# Invalid JSON detected: 21083.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21083.json
# Invalid JSON detected: 23168.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23168.json
# Invalid JSON detected: 15823.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15823.json
# Invalid JSON detected: 21370.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21370.json
# 23866.json is a valid JSON file.
# Invalid JSON detected: 29273.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29273.json
# 18662.json is a valid JSON file.
# 2796.json is a valid JSON file.
# 33363.json is a valid JSON file.
# 24406.json is a valid JSON file.
# Invalid JSON detected: 33155.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33155.json
# 5931.json is a valid JSON file.
# 6966.json is a valid JSON file.
# Invalid JSON detected: 7153.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7153.json
# Invalid JSON detected: 3878.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3878.json
# 31932.json is a valid JSON file.
# 26173.json is a valid JSON file.
# Invalid JSON detected: 13176.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13176.json
# 19141.json is a valid JSON file.
# Invalid JSON detected: 21356.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21356.json
# 34510.json is a valid JSON file.
# 30118.json is a valid JSON file.
# Invalid JSON detected: 19741.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19741.json
# 8629.json is a valid JSON file.
# Invalid JSON detected: 11059.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11059.json
# 16680.json is a valid JSON file.
# Invalid JSON detected: 8855.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8855.json
# Invalid JSON detected: 34567.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34567.json
# 12139.json is a valid JSON file.
# Invalid JSON detected: 29080.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29080.json
# 30290.json is a valid JSON file.
# Invalid JSON detected: 8254.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8254.json
# Invalid JSON detected: 26591.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26591.json
# 35592.json is a valid JSON file.
# Invalid JSON detected: 32859.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32859.json
# Invalid JSON detected: 8443.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8443.json
# 24737.json is a valid JSON file.
# Invalid JSON detected: 15347.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15347.json
# 9480.json is a valid JSON file.
# Invalid JSON detected: 33862.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33862.json
# Invalid JSON detected: 28734.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28734.json
# Invalid JSON detected: 26950.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26950.json
# Invalid JSON detected: 4264.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4264.json
# Invalid JSON detected: 13732.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13732.json
# Invalid JSON detected: 32109.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32109.json
# Invalid JSON detected: 5490.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5490.json
# Invalid JSON detected: 27841.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27841.json
# Invalid JSON detected: 13655.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13655.json
# 33164.json is a valid JSON file.
# 27605.json is a valid JSON file.
# Invalid JSON detected: 11196.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11196.json
# Invalid JSON detected: 37655.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37655.json
# Invalid JSON detected: 30091.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30091.json
# Invalid JSON detected: 10887.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10887.json
# Invalid JSON detected: 24543.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24543.json
# 34310.json is a valid JSON file.
# Invalid JSON detected: 21507.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21507.json
# 5320.json is a valid JSON file.
# Invalid JSON detected: 21969.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21969.json
# Invalid JSON detected: 5277.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5277.json
# 6440.json is a valid JSON file.
# 8063.json is a valid JSON file.
# 37102.json is a valid JSON file.
# Invalid JSON detected: 9669.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9669.json
# 10900.json is a valid JSON file.
# 20233.json is a valid JSON file.
# 10375.json is a valid JSON file.
# Invalid JSON detected: 35648.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/35648.json
# Invalid JSON detected: 22196.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22196.json
# 26088.json is a valid JSON file.
# Invalid JSON detected: 9555.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9555.json
# Invalid JSON detected: 28339.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28339.json
# 10139.json is a valid JSON file.
# Invalid JSON detected: 26777.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26777.json
# 30876.json is a valid JSON file.
# Invalid JSON detected: 17298.json, attempting to fix...
# Error fixing leaflet_jsons/17298.json: Invalid control character at: line 72 column 171 (char 2621)
# 28659.json is a valid JSON file.
# 32606.json is a valid JSON file.
# 27530.json is a valid JSON file.
# Invalid JSON detected: 12911.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12911.json
# 24006.json is a valid JSON file.
# Invalid JSON detected: 28559.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28559.json
# Invalid JSON detected: 29439.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29439.json
# Invalid JSON detected: 4886.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4886.json
# 34053.json is a valid JSON file.
# 33372.json is a valid JSON file.
# 37404.json is a valid JSON file.
# 38926.json is a valid JSON file.
# Invalid JSON detected: 32748.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32748.json
# Invalid JSON detected: 23891.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23891.json
# Invalid JSON detected: 30345.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30345.json
# Invalid JSON detected: 22968.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22968.json
# Invalid JSON detected: 37235.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37235.json
# 15577.json is a valid JSON file.
# Invalid JSON detected: 22521.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22521.json
# Invalid JSON detected: 24169.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24169.json
# Invalid JSON detected: 25274.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/25274.json
# Invalid JSON detected: 21037.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21037.json
# Invalid JSON detected: 8195.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8195.json
# 37341.json is a valid JSON file.
# Invalid JSON detected: 32473.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32473.json
# Invalid JSON detected: 25266.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/25266.json
# Invalid JSON detected: 3230.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3230.json
# Invalid JSON detected: 34182.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34182.json
# 36820.json is a valid JSON file.
# Invalid JSON detected: 26561.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26561.json
# 16549.json is a valid JSON file.
# Invalid JSON detected: 5946.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5946.json
# Invalid JSON detected: 34915.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34915.json
# 34083.json is a valid JSON file.
# 5095.json is a valid JSON file.
# Invalid JSON detected: 34449.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34449.json
# 18637.json is a valid JSON file.
# Invalid JSON detected: 30194.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30194.json
# 26014.json is a valid JSON file.
# Invalid JSON detected: 3843.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3843.json
# Invalid JSON detected: 4994.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4994.json
# 21293.json is a valid JSON file.
# Invalid JSON detected: 6867.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6867.json
# Invalid JSON detected: 20956.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20956.json
# Invalid JSON detected: 17839.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17839.json
# 32529.json is a valid JSON file.
# Invalid JSON detected: 7380.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7380.json
# Invalid JSON detected: 5176.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5176.json
# Invalid JSON detected: 11350.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11350.json
# Invalid JSON detected: 12657.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12657.json
# Invalid JSON detected: 28166.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28166.json
# Invalid JSON detected: 12821.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12821.json
# Invalid JSON detected: 12569.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12569.json
# Invalid JSON detected: 30613.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30613.json
# Invalid JSON detected: 9088.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9088.json
# Invalid JSON detected: 32231.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32231.json
# 26517.json is a valid JSON file.
# 3558.json is a valid JSON file.
# 12462.json is a valid JSON file.
# Invalid JSON detected: 16524.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16524.json
# 26613.json is a valid JSON file.
# 38763.json is a valid JSON file.
# 20137.json is a valid JSON file.
# Invalid JSON detected: 17764.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17764.json
# 5939.json is a valid JSON file.
# Invalid JSON detected: 22617.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22617.json
# Invalid JSON detected: 7354.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7354.json
# Invalid JSON detected: 23247.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23247.json
# Invalid JSON detected: 27331.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27331.json
# 16079.json is a valid JSON file.
# 7812.json is a valid JSON file.
# Invalid JSON detected: 31302.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31302.json
# Invalid JSON detected: 3073.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3073.json
# Invalid JSON detected: 24465.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24465.json
# Invalid JSON detected: 11509.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11509.json
# Invalid JSON detected: 30779.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30779.json
# Invalid JSON detected: 22120.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22120.json
# 31428.json is a valid JSON file.
# Invalid JSON detected: 19201.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19201.json
# Invalid JSON detected: 7386.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7386.json
# 30339.json is a valid JSON file.
# 21382.json is a valid JSON file.
# Invalid JSON detected: 19116.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19116.json
# 7453.json is a valid JSON file.
# 6232.json is a valid JSON file.
# 5697.json is a valid JSON file.
# 16426.json is a valid JSON file.
# Invalid JSON detected: 28177.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28177.json
# 30220.json is a valid JSON file.
# Invalid JSON detected: 5098.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5098.json
# 27191.json is a valid JSON file.
# 20520.json is a valid JSON file.
# 21223.json is a valid JSON file.
# 33646.json is a valid JSON file.
# Invalid JSON detected: 28023.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28023.json
# Invalid JSON detected: 4211.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4211.json
# Invalid JSON detected: 28656.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28656.json
# Invalid JSON detected: 11632.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11632.json
# Invalid JSON detected: 34029.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34029.json
# Invalid JSON detected: 30711.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30711.json
# 29188.json is a valid JSON file.
# Invalid JSON detected: 35064.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/35064.json
# 12591.json is a valid JSON file.
# 25092.json is a valid JSON file.
# Invalid JSON detected: 28311.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28311.json
# 22237.json is a valid JSON file.
# Invalid JSON detected: 5462.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5462.json
# Invalid JSON detected: 6399.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6399.json
# Invalid JSON detected: 26935.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26935.json
# 25799.json is a valid JSON file.
# Invalid JSON detected: 2952.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/2952.json
# Invalid JSON detected: 3311.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3311.json
# 28591.json is a valid JSON file.
# 27787.json is a valid JSON file.
# 29118.json is a valid JSON file.
# Invalid JSON detected: 33633.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33633.json
# Invalid JSON detected: 11607.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11607.json
# 11113.json is a valid JSON file.
# Invalid JSON detected: 34500.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34500.json
# 28050.json is a valid JSON file.
# 29098.json is a valid JSON file.
# Invalid JSON detected: 7137.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7137.json
# Invalid JSON detected: 38921.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/38921.json
# Invalid JSON detected: 25904.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/25904.json
# Invalid JSON detected: 37864.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37864.json
# 25038.json is a valid JSON file.
# Invalid JSON detected: 7143.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7143.json
# Invalid JSON detected: 10153.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10153.json
# 38799.json is a valid JSON file.
# Invalid JSON detected: 27245.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27245.json
# Invalid JSON detected: 34958.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34958.json
# Invalid JSON detected: 15537.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15537.json
# 5898.json is a valid JSON file.
# Invalid JSON detected: 24655.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24655.json
# Invalid JSON detected: 12084.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12084.json
# Invalid JSON detected: 18789.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18789.json
# Invalid JSON detected: 7952.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7952.json
# 5181.json is a valid JSON file.
# 16558.json is a valid JSON file.
# 32581.json is a valid JSON file.
# 23138.json is a valid JSON file.
# 23175.json is a valid JSON file.
# Invalid JSON detected: 10928.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10928.json
# Invalid JSON detected: 17150.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17150.json
# Invalid JSON detected: 8517.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8517.json
# Invalid JSON detected: 27257.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27257.json
# 16147.json is a valid JSON file.
# Invalid JSON detected: 11209.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11209.json
# Invalid JSON detected: 6096.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6096.json
# 37433.json is a valid JSON file.
# 33463.json is a valid JSON file.
# Invalid JSON detected: 4171.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4171.json
# Invalid JSON detected: 34976.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34976.json
# Invalid JSON detected: 4527.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4527.json
# Invalid JSON detected: 12291.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12291.json
# Invalid JSON detected: 37189.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37189.json
# Invalid JSON detected: 33598.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33598.json
# Invalid JSON detected: 17832.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17832.json
# Invalid JSON detected: 30726.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30726.json
# 6492.json is a valid JSON file.
# Invalid JSON detected: 10684.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10684.json
# Invalid JSON detected: 10013.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10013.json
# Invalid JSON detected: 27282.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27282.json
# Invalid JSON detected: 23060.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23060.json
# Invalid JSON detected: 23048.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23048.json
# 34540.json is a valid JSON file.
# 8323.json is a valid JSON file.
# 34277.json is a valid JSON file.
# 32237.json is a valid JSON file.
# Invalid JSON detected: 25843.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/25843.json
# Invalid JSON detected: 11925.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11925.json
# 37485.json is a valid JSON file.
# Invalid JSON detected: 9749.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/9749.json
# 10249.json is a valid JSON file.
# 15256.json is a valid JSON file.
# Invalid JSON detected: 14685.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/14685.json
# 21665.json is a valid JSON file.
# 8885.json is a valid JSON file.
# Invalid JSON detected: 37716.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37716.json
# Invalid JSON detected: 32639.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32639.json
# Invalid JSON detected: 16592.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16592.json
# Invalid JSON detected: 13768.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13768.json
# Invalid JSON detected: 26394.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26394.json
# Invalid JSON detected: 21296.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21296.json
# 34071.json is a valid JSON file.
# Invalid JSON detected: 11072.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11072.json
# Invalid JSON detected: 17564.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17564.json
# 11952.json is a valid JSON file.
# 33639.json is a valid JSON file.
# 20995.json is a valid JSON file.
# 24319.json is a valid JSON file.
# Invalid JSON detected: 37798.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37798.json
# Invalid JSON detected: 26909.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26909.json
# Invalid JSON detected: 19167.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19167.json
# 25715.json is a valid JSON file.
# Invalid JSON detected: 27426.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27426.json
# Invalid JSON detected: 19433.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19433.json
# 30596.json is a valid JSON file.
# Invalid JSON detected: 21736.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21736.json
# 27432.json is a valid JSON file.
# Invalid JSON detected: 33692.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33692.json
# 34760.json is a valid JSON file.
# Invalid JSON detected: 34724.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34724.json
# Invalid JSON detected: 5351.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5351.json
# Invalid JSON detected: 29229.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29229.json
# Invalid JSON detected: 31320.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31320.json
# Invalid JSON detected: 14873.json, attempting to fix...
# Error fixing leaflet_jsons/14873.json: Expecting ',' delimiter: line 69 column 158 (char 3305)
# Invalid JSON detected: 28984.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28984.json
# Invalid JSON detected: 26237.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26237.json
# Invalid JSON detected: 13849.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13849.json
# Invalid JSON detected: 38702.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/38702.json
# Invalid JSON detected: 11408.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11408.json
# 22015.json is a valid JSON file.
# Invalid JSON detected: 6156.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6156.json
# Invalid JSON detected: 13635.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13635.json
# 23243.json is a valid JSON file.
# Invalid JSON detected: 21574.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21574.json
# Invalid JSON detected: 7180.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7180.json
# 31634.json is a valid JSON file.
# 26110.json is a valid JSON file.
# 17640.json is a valid JSON file.
# 11598.json is a valid JSON file.
# 32844.json is a valid JSON file.
# 23203.json is a valid JSON file.
# Invalid JSON detected: 30397.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30397.json
# Invalid JSON detected: 12974.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12974.json
# Invalid JSON detected: 6563.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6563.json
# Invalid JSON detected: 18889.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18889.json
# Invalid JSON detected: 5219.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5219.json
# 30072.json is a valid JSON file.
# Invalid JSON detected: 10073.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10073.json
# Invalid JSON detected: 29170.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29170.json
# 32901.json is a valid JSON file.
# 11673.json is a valid JSON file.
# 15080.json is a valid JSON file.
# Invalid JSON detected: 5036.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5036.json
# 24923.json is a valid JSON file.
# 10388.json is a valid JSON file.
# Invalid JSON detected: 15880.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15880.json
# Invalid JSON detected: 34845.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34845.json
# 5778.json is a valid JSON file.
# Invalid JSON detected: 10814.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10814.json
# 29173.json is a valid JSON file.
# Invalid JSON detected: 5066.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5066.json
# Invalid JSON detected: 34443.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34443.json
# 4079.json is a valid JSON file.
# 9672.json is a valid JSON file.
# Invalid JSON detected: 22869.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22869.json
# 26508.json is a valid JSON file.
# 9643.json is a valid JSON file.
# Invalid JSON detected: 3181.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3181.json
# Invalid JSON detected: 24261.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24261.json
# 37217.json is a valid JSON file.
# Invalid JSON detected: 28302.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28302.json
# Invalid JSON detected: 17659.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17659.json
# 26196.json is a valid JSON file.
# Invalid JSON detected: 27650.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27650.json
# Invalid JSON detected: 37681.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37681.json
# Invalid JSON detected: 18499.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18499.json
# ...
# Fixed and saved valid JSON to leaflet_jsons/4481.json
# 23788.json is a valid JSON file.
# Invalid JSON detected: 2786.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/2786.json
# Invalid JSON detected: 26399.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26399.json
# Invalid JSON detected: 14801.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/14801.json
# 7307.json is a valid JSON file.
# Invalid JSON detected: 8939.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8939.json
# Invalid JSON detected: 26301.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26301.json
# 4576.json is a valid JSON file.
# 9640.json is a valid JSON file.
# Invalid JSON detected: 3326.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3326.json
# Invalid JSON detected: 38880.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/38880.json
# Invalid JSON detected: 22904.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22904.json
# Invalid JSON detected: 37252.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37252.json
# Invalid JSON detected: 24992.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24992.json
# Invalid JSON detected: 32102.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32102.json
# Invalid JSON detected: 5856.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5856.json
# 34462.json is a valid JSON file.
# 37480.json is a valid JSON file.
# Invalid JSON detected: 37769.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37769.json
# 21815.json is a valid JSON file.
# Invalid JSON detected: 18641.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18641.json
# 28501.json is a valid JSON file.
# 28698.json is a valid JSON file.
# Invalid JSON detected: 22037.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/22037.json
# Invalid JSON detected: 24554.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24554.json
# 20320.json is a valid JSON file.
# Invalid JSON detected: 37086.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37086.json
# Invalid JSON detected: 28337.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28337.json
# Invalid JSON detected: 20399.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20399.json
# Invalid JSON detected: 8456.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8456.json
# Invalid JSON detected: 11988.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11988.json
# Invalid JSON detected: 27218.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27218.json
# Invalid JSON detected: 13505.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/13505.json
# 33150.json is a valid JSON file.
# Invalid JSON detected: 30447.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30447.json
# Invalid JSON detected: 21043.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/21043.json
# 11369.json is a valid JSON file.
# Invalid JSON detected: 11129.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11129.json
# Invalid JSON detected: 37640.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37640.json
# Invalid JSON detected: 29523.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29523.json
# Invalid JSON detected: 12404.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12404.json
# 21252.json is a valid JSON file.
# Invalid JSON detected: 19422.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19422.json
# Invalid JSON detected: 7665.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7665.json
# Invalid JSON detected: 30563.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30563.json
# Invalid JSON detected: 33351.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33351.json
# Invalid JSON detected: 36859.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/36859.json
# 33414.json is a valid JSON file.
# 25535.json is a valid JSON file.
# 32623.json is a valid JSON file.
# Invalid JSON detected: 7856.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7856.json
# Invalid JSON detected: 34782.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34782.json
# Invalid JSON detected: 6368.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6368.json
# Invalid JSON detected: 25048.json, attempting to fix...
# Error fixing leaflet_jsons/25048.json: Expecting ',' delimiter: line 41 column 8 (char 1192)
# 32445.json is a valid JSON file.
# Invalid JSON detected: 17454.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17454.json
# 26262.json is a valid JSON file.
# Invalid JSON detected: 23224.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/23224.json
# Invalid JSON detected: 18380.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18380.json
# 24265.json is a valid JSON file.
# 5627.json is a valid JSON file.
# Invalid JSON detected: 6785.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6785.json
# 16929.json is a valid JSON file.
# Invalid JSON detected: 28256.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28256.json
# 3851.json is a valid JSON file.
# Invalid JSON detected: 33354.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33354.json
# Invalid JSON detected: 38658.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/38658.json
# 22603.json is a valid JSON file.
# 25907.json is a valid JSON file.
# Invalid JSON detected: 32327.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/32327.json
# 3134.json is a valid JSON file.
# 22069.json is a valid JSON file.
# 23933.json is a valid JSON file.
# 10213.json is a valid JSON file.
# Invalid JSON detected: 6700.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6700.json
# 30300.json is a valid JSON file.
# 29320.json is a valid JSON file.
# 2893.json is a valid JSON file.
# 24258.json is a valid JSON file.
# 30926.json is a valid JSON file.
# Invalid JSON detected: 31956.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31956.json
# 23690.json is a valid JSON file.
# Invalid JSON detected: 10464.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10464.json
# 32597.json is a valid JSON file.
# Invalid JSON detected: 19374.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/19374.json
# Invalid JSON detected: 17548.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17548.json
# 18627.json is a valid JSON file.
# Invalid JSON detected: 16435.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16435.json
# Invalid JSON detected: 16181.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16181.json
# Invalid JSON detected: 2837.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/2837.json
# Invalid JSON detected: 10294.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10294.json
# Invalid JSON detected: 12878.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12878.json
# Invalid JSON detected: 20795.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20795.json
# Invalid JSON detected: 30134.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30134.json
# Invalid JSON detected: 31185.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31185.json
# Invalid JSON detected: 10191.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10191.json
# Invalid JSON detected: 5377.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5377.json
# Invalid JSON detected: 31707.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31707.json
# Invalid JSON detected: 6979.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/6979.json
# 32288.json is a valid JSON file.
# Invalid JSON detected: 10355.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10355.json
# Invalid JSON detected: 3980.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3980.json
# 3883.json is a valid JSON file.
# 16055.json is a valid JSON file.
# Invalid JSON detected: 37258.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37258.json
# Invalid JSON detected: 33491.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33491.json
# 38082.json is a valid JSON file.
# Invalid JSON detected: 11772.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11772.json
# Invalid JSON detected: 4873.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4873.json
# Invalid JSON detected: 14827.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/14827.json
# Invalid JSON detected: 2988.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/2988.json
# Invalid JSON detected: 33244.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/33244.json
# Invalid JSON detected: 37117.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37117.json
# Invalid JSON detected: 5916.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5916.json
# 9399.json is a valid JSON file.
# 8000.json is a valid JSON file.
# Invalid JSON detected: 18348.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/18348.json
# 27180.json is a valid JSON file.
# 37600.json is a valid JSON file.
# Invalid JSON detected: 5582.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5582.json
# Invalid JSON detected: 8652.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8652.json
# 9532.json is a valid JSON file.
# Invalid JSON detected: 31721.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31721.json
# Invalid JSON detected: 8597.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8597.json
# 15231.json is a valid JSON file.
# 34220.json is a valid JSON file.
# Invalid JSON detected: 31488.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31488.json
# Invalid JSON detected: 4372.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4372.json
# 31121.json is a valid JSON file.
# Invalid JSON detected: 8136.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8136.json
# Invalid JSON detected: 3968.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/3968.json
# 9239.json is a valid JSON file.
# Invalid JSON detected: 27821.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/27821.json
# Invalid JSON detected: 8424.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8424.json
# Invalid JSON detected: 7990.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7990.json
# Invalid JSON detected: 17348.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17348.json
# 34196.json is a valid JSON file.
# 32471.json is a valid JSON file.
# Invalid JSON detected: 20870.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20870.json
# Invalid JSON detected: 12530.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12530.json
# Invalid JSON detected: 16509.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16509.json
# Invalid JSON detected: 4066.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4066.json
# Invalid JSON detected: 30838.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30838.json
# 31071.json is a valid JSON file.
# 20474.json is a valid JSON file.
# Invalid JSON detected: 24249.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24249.json
# 34546.json is a valid JSON file.
# 24040.json is a valid JSON file.
# Invalid JSON detected: 29530.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29530.json
# Invalid JSON detected: 5980.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5980.json
# 13513.json is a valid JSON file.
# Invalid JSON detected: 7842.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7842.json
# 6503.json is a valid JSON file.
# Invalid JSON detected: 31118.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31118.json
# Invalid JSON detected: 5327.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5327.json
# Invalid JSON detected: 11110.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/11110.json
# 15806.json is a valid JSON file.
# Invalid JSON detected: 30042.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/30042.json
# Invalid JSON detected: 5129.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/5129.json
# Invalid JSON detected: 7495.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/7495.json
# Invalid JSON detected: 24806.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/24806.json
# Invalid JSON detected: 26722.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26722.json
# Invalid JSON detected: 29007.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/29007.json
# Invalid JSON detected: 15489.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15489.json
# Invalid JSON detected: 25943.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/25943.json
# Invalid JSON detected: 26470.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/26470.json
# 17247.json is a valid JSON file.
# Invalid JSON detected: 10263.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10263.json
# 32207.json is a valid JSON file.
# Invalid JSON detected: 2828.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/2828.json
# Invalid JSON detected: 12720.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12720.json
# 33409.json is a valid JSON file.
# 3770.json is a valid JSON file.
# Invalid JSON detected: 31944.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/31944.json
# Invalid JSON detected: 8118.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/8118.json
# Invalid JSON detected: 37689.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/37689.json
# Invalid JSON detected: 16499.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16499.json
# Invalid JSON detected: 4208.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/4208.json
# 33068.json is a valid JSON file.
# Invalid JSON detected: 20471.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/20471.json
# Invalid JSON detected: 12313.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/12313.json
# 18773.json is a valid JSON file.
# 9470.json is a valid JSON file.
# 4393.json is a valid JSON file.
# Invalid JSON detected: 10040.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/10040.json
# Invalid JSON detected: 16447.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/16447.json
# Invalid JSON detected: 34214.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/34214.json
# Invalid JSON detected: 15673.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/15673.json
# Invalid JSON detected: 17345.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/17345.json
# Invalid JSON detected: 28355.json, attempting to fix...
# Fixed and saved valid JSON to leaflet_jsons/28355.json
# 30738.json is a valid JSON file.

# %%
import json
import os
import shutil  # For moving files

def check_json_structure(file_path):
    """Check if JSON file adheres to the specified structure."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON in {file_path}: {e}")
        return False  # Indicating that this file does not adhere due to a JSON error
        
    # Define the expected structure
    expected_structure = {
        "leaflet": {
            "candidateName": str,
            "constituency": str,
            "politicalParty": str,
            "electionDate": str,
            "messages": list,
            "keyPolicies": list,
            "mentions": {
                "candidate": str,
                "otherPartyLeaderCandidate": str,
                "partyLeader": str,
                "tacticalSituation": str
            },
            "issues": {
                "brexitEurope": str,
                "economy": str,
                "education": str,
                "environment": str,
                "governance": str,
                "health": str,
                "immigration": str,
                "socialWelfare": str,
                "housing": list
            },
            "personalStatement": str,
            "politicalExperience": list,
            "contactInformation": {
                "address": str,
                "phone": str,
                "email": str,
                "website": str,
                "socialMedia": {
                    "facebook": str,
                    "twitter": str,
                    "instagram": str,
                    "linkedin": str
                }
            },
            "endorsements": list,
            "quotes": list,
            "campaignMaterial": {
                "images": list
            },
            "additionalNotes": str
        }
    }

    def check_structure(data, structure):
        if type(data) is not dict or type(structure) is not dict:
            return type(data) == structure
        for key, value_type in structure.items():
            if key not in data or not check_structure(data[key], value_type):
                return False
        return True

    return check_structure(data, expected_structure)

def process_directory_for_structure(directory_path):
    faulty_dir = os.path.join(directory_path, "faulty")
    if not os.path.exists(faulty_dir):
        os.makedirs(faulty_dir)

    num_bad = 0
    for filename in os.listdir(directory_path):
        if filename.endswith('.json'):
            file_path = os.path.join(directory_path, filename)
            if not check_json_structure(file_path):
                print(f"{filename} does not adhere to the specified format.")
                faulty_file_path = os.path.join(faulty_dir, filename)
                shutil.move(file_path, faulty_file_path)  # Move the file to the "faulty" directory
                num_bad += 1
    print(f"Moved {num_bad} files to the faulty directory.")

# Replace 'your_directory_path' with the path to your directory containing JSON files
directory_path = 'leaflet_jsons'
process_directory_for_structure(directory_path)
# Out:
# 19761.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/13185.json: Invalid control character at: line 87 column 113 (char 5701)
# 13185.json does not adhere to the specified format.
# 29155.json does not adhere to the specified format.
# 31737.json does not adhere to the specified format.
# 12989.json does not adhere to the specified format.
# 10788.json does not adhere to the specified format.
# 3296.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/37885.json: Expecting value: line 1 column 1 (char 0)
# 37885.json does not adhere to the specified format.
# 10811.json does not adhere to the specified format.
# 28626.json does not adhere to the specified format.
# 15823.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/17298.json: Expecting value: line 1 column 1 (char 0)
# 17298.json does not adhere to the specified format.
# 29439.json does not adhere to the specified format.
# 38926.json does not adhere to the specified format.
# 7386.json does not adhere to the specified format.
# 30220.json does not adhere to the specified format.
# 22237.json does not adhere to the specified format.
# 16558.json does not adhere to the specified format.
# 23060.json does not adhere to the specified format.
# 9749.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/14873.json: Expecting value: line 1 column 1 (char 0)
# 14873.json does not adhere to the specified format.
# 24536.json does not adhere to the specified format.
# 28990.json does not adhere to the specified format.
# 13821.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/8891.json: Expecting value: line 1 column 1 (char 0)
# 8891.json does not adhere to the specified format.
# 23312.json does not adhere to the specified format.
# 34307.json does not adhere to the specified format.
# 28782.json does not adhere to the specified format.
# 28705.json does not adhere to the specified format.
# 26659.json does not adhere to the specified format.
# 35561.json does not adhere to the specified format.
# 17050.json does not adhere to the specified format.
# 18351.json does not adhere to the specified format.
# 9560.json does not adhere to the specified format.
# 26616.json does not adhere to the specified format.
# 29844.json does not adhere to the specified format.
# 24850.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/13484.json: Expecting value: line 1 column 1 (char 0)
# 13484.json does not adhere to the specified format.
# 35003.json does not adhere to the specified format.
# 15411.json does not adhere to the specified format.
# 5570.json does not adhere to the specified format.
# 28148.json does not adhere to the specified format.
# 34713.json does not adhere to the specified format.
# 28444.json does not adhere to the specified format.
# 30156.json does not adhere to the specified format.
# 17545.json does not adhere to the specified format.
# 12475.json does not adhere to the specified format.
# 24505.json does not adhere to the specified format.
# 22785.json does not adhere to the specified format.
# 25734.json does not adhere to the specified format.
# 29419.json does not adhere to the specified format.
# 16187.json does not adhere to the specified format.
# 28683.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/9058.json: Expecting value: line 1 column 1 (char 0)
# 9058.json does not adhere to the specified format.
# 37623.json does not adhere to the specified format.
# 31106.json does not adhere to the specified format.
# 24009.json does not adhere to the specified format.
# 27734.json does not adhere to the specified format.
# 30366.json does not adhere to the specified format.
# 39094.json does not adhere to the specified format.
# 14967.json does not adhere to the specified format.
# 24303.json does not adhere to the specified format.
# 34653.json does not adhere to the specified format.
# 24435.json does not adhere to the specified format.
# 22537.json does not adhere to the specified format.
# 3797.json does not adhere to the specified format.
# 5633.json does not adhere to the specified format.
# 37807.json does not adhere to the specified format.
# 32676.json does not adhere to the specified format.
# 5481.json does not adhere to the specified format.
# 9094.json does not adhere to the specified format.
# 15519.json does not adhere to the specified format.
# 6431.json does not adhere to the specified format.
# 22158.json does not adhere to the specified format.
# 24672.json does not adhere to the specified format.
# 9490.json does not adhere to the specified format.
# 13418.json does not adhere to the specified format.
# 9912.json does not adhere to the specified format.
# 11650.json does not adhere to the specified format.
# 23272.json does not adhere to the specified format.
# 30917.json does not adhere to the specified format.
# 28756.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/25958.json: Expecting value: line 1 column 1 (char 0)
# 25958.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/10723.json: Expecting value: line 1 column 1 (char 0)
# 10723.json does not adhere to the specified format.
# 24214.json does not adhere to the specified format.
# 4008.json does not adhere to the specified format.
# 18944.json does not adhere to the specified format.
# 25080.json does not adhere to the specified format.
# 25209.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/23151.json: Expecting value: line 1 column 1 (char 0)
# 23151.json does not adhere to the specified format.
# 24241.json does not adhere to the specified format.
# 16354.json does not adhere to the specified format.
# 31562.json does not adhere to the specified format.
# 15916.json does not adhere to the specified format.
# 23643.json does not adhere to the specified format.
# 34767.json does not adhere to the specified format.
# 30250.json does not adhere to the specified format.
# 23095.json does not adhere to the specified format.
# 22211.json does not adhere to the specified format.
# 6360.json does not adhere to the specified format.
# 21988.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/13287.json: Expecting value: line 1 column 1 (char 0)
# 13287.json does not adhere to the specified format.
# 8808.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/9706.json: Expecting value: line 1 column 1 (char 0)
# 9706.json does not adhere to the specified format.
# 6873.json does not adhere to the specified format.
# 24496.json does not adhere to the specified format.
# 27023.json does not adhere to the specified format.
# 6486.json does not adhere to the specified format.
# 15282.json does not adhere to the specified format.
# 20743.json does not adhere to the specified format.
# 21705.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/15595.json: Expecting value: line 1 column 1 (char 0)
# 15595.json does not adhere to the specified format.
# 20265.json does not adhere to the specified format.
# 28803.json does not adhere to the specified format.
# 33027.json does not adhere to the specified format.
# 19079.json does not adhere to the specified format.
# 9225.json does not adhere to the specified format.
# 21088.json does not adhere to the specified format.
# 26384.json does not adhere to the specified format.
# 32489.json does not adhere to the specified format.
# 20960.json does not adhere to the specified format.
# 20749.json does not adhere to the specified format.
# 38696.json does not adhere to the specified format.
# 27767.json does not adhere to the specified format.
# 10866.json does not adhere to the specified format.
# 5557.json does not adhere to the specified format.
# 24379.json does not adhere to the specified format.
# 14744.json does not adhere to the specified format.
# 7535.json does not adhere to the specified format.
# 34304.json does not adhere to the specified format.
# 20544.json does not adhere to the specified format.
# 29250.json does not adhere to the specified format.
# 30821.json does not adhere to the specified format.
# 8233.json does not adhere to the specified format.
# 30467.json does not adhere to the specified format.
# 28169.json does not adhere to the specified format.
# 37652.json does not adhere to the specified format.
# 30034.json does not adhere to the specified format.
# 12746.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/10806.json: Expecting value: line 1 column 1 (char 0)
# 10806.json does not adhere to the specified format.
# 21901.json does not adhere to the specified format.
# 22734.json does not adhere to the specified format.
# 5047.json does not adhere to the specified format.
# 16965.json does not adhere to the specified format.
# 2965.json does not adhere to the specified format.
# 3368.json does not adhere to the specified format.
# 3870.json does not adhere to the specified format.
# 26860.json does not adhere to the specified format.
# 32338.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/4698.json: Expecting ',' delimiter: line 22 column 7 (char 715)
# 4698.json does not adhere to the specified format.
# 35112.json does not adhere to the specified format.
# 22247.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/11706.json: Expecting ',' delimiter: line 48 column 68 (char 2328)
# 11706.json does not adhere to the specified format.
# 13724.json does not adhere to the specified format.
# 25952.json does not adhere to the specified format.
# 29332.json does not adhere to the specified format.
# 17422.json does not adhere to the specified format.
# 22879.json does not adhere to the specified format.
# 26719.json does not adhere to the specified format.
# 10977.json does not adhere to the specified format.
# 28665.json does not adhere to the specified format.
# 23103.json does not adhere to the specified format.
# 17289.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/4933.json: Expecting ',' delimiter: line 45 column 11 (char 1724)
# 4933.json does not adhere to the specified format.
# 12178.json does not adhere to the specified format.
# 27794.json does not adhere to the specified format.
# 16025.json does not adhere to the specified format.
# 38824.json does not adhere to the specified format.
# 31213.json does not adhere to the specified format.
# 28952.json does not adhere to the specified format.
# 13395.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/27883.json: Expecting ',' delimiter: line 109 column 9 (char 4386)
# 27883.json does not adhere to the specified format.
# 4450.json does not adhere to the specified format.
# 22568.json does not adhere to the specified format.
# 3385.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/25961.json: Expecting ',' delimiter: line 16 column 73 (char 548)
# 25961.json does not adhere to the specified format.
# 20050.json does not adhere to the specified format.
# 28157.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/6529.json: Expecting value: line 1 column 1 (char 0)
# 6529.json does not adhere to the specified format.
# 37745.json does not adhere to the specified format.
# 37402.json does not adhere to the specified format.
# 7069.json does not adhere to the specified format.
# 24604.json does not adhere to the specified format.
# 37583.json does not adhere to the specified format.
# 34809.json does not adhere to the specified format.
# 4224.json does not adhere to the specified format.
# 7300.json does not adhere to the specified format.
# 25666.json does not adhere to the specified format.
# 26794.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/12645.json: Expecting ',' delimiter: line 41 column 100 (char 1379)
# 12645.json does not adhere to the specified format.
# 18241.json does not adhere to the specified format.
# 24902.json does not adhere to the specified format.
# 15479.json does not adhere to the specified format.
# 22043.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/37628.json: Expecting value: line 1 column 1 (char 0)
# 37628.json does not adhere to the specified format.
# 37300.json does not adhere to the specified format.
# 14627.json does not adhere to the specified format.
# 6053.json does not adhere to the specified format.
# 32510.json does not adhere to the specified format.
# 31179.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/17374.json: Invalid control character at: line 76 column 111 (char 2395)
# 17374.json does not adhere to the specified format.
# 20165.json does not adhere to the specified format.
# 34121.json does not adhere to the specified format.
# 22161.json does not adhere to the specified format.
# 32294.json does not adhere to the specified format.
# 8982.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/5605.json: Expecting value: line 1 column 1 (char 0)
# 5605.json does not adhere to the specified format.
# 13541.json does not adhere to the specified format.
# 25239.json does not adhere to the specified format.
# 29793.json does not adhere to the specified format.
# 22164.json does not adhere to the specified format.
# 29139.json does not adhere to the specified format.
# 17257.json does not adhere to the specified format.
# 39050.json does not adhere to the specified format.
# 35148.json does not adhere to the specified format.
# 25137.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/18913.json: Expecting value: line 1 column 1 (char 0)
# 18913.json does not adhere to the specified format.
# 25286.json does not adhere to the specified format.
# 23596.json does not adhere to the specified format.
# 15374.json does not adhere to the specified format.
# 5470.json does not adhere to the specified format.
# 3443.json does not adhere to the specified format.
# 30205.json does not adhere to the specified format.
# 11035.json does not adhere to the specified format.
# 18288.json does not adhere to the specified format.
# 34590.json does not adhere to the specified format.
# 12883.json does not adhere to the specified format.
# 30619.json does not adhere to the specified format.
# 28478.json does not adhere to the specified format.
# 30065.json does not adhere to the specified format.
# 14851.json does not adhere to the specified format.
# 5541.json does not adhere to the specified format.
# 21202.json does not adhere to the specified format.
# 29868.json does not adhere to the specified format.
# 12560.json does not adhere to the specified format.
# 27616.json does not adhere to the specified format.
# 34077.json does not adhere to the specified format.
# 32481.json does not adhere to the specified format.
# 20236.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/15840.json: Expecting value: line 1 column 1 (char 0)
# 15840.json does not adhere to the specified format.
# 9949.json does not adhere to the specified format.
# 29763.json does not adhere to the specified format.
# 7726.json does not adhere to the specified format.
# 18692.json does not adhere to the specified format.
# 33729.json does not adhere to the specified format.
# 20980.json does not adhere to the specified format.
# 26396.json does not adhere to the specified format.
# 37934.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/5393.json: Expecting ',' delimiter: line 39 column 7 (char 1236)
# 5393.json does not adhere to the specified format.
# 11051.json does not adhere to the specified format.
# 27784.json does not adhere to the specified format.
# 7351.json does not adhere to the specified format.
# 4011.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/33275.json: Expecting value: line 1 column 1 (char 0)
# 33275.json does not adhere to the specified format.
# 29022.json does not adhere to the specified format.
# 5553.json does not adhere to the specified format.
# 15740.json does not adhere to the specified format.
# 2939.json does not adhere to the specified format.
# 6424.json does not adhere to the specified format.
# 17188.json does not adhere to the specified format.
# 26097.json does not adhere to the specified format.
# 16310.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/9419.json: Expecting value: line 1 column 1 (char 0)
# 9419.json does not adhere to the specified format.
# 14879.json does not adhere to the specified format.
# 20053.json does not adhere to the specified format.
# 27818.json does not adhere to the specified format.
# 30003.json does not adhere to the specified format.
# 9473.json does not adhere to the specified format.
# 34098.json does not adhere to the specified format.
# 31520.json does not adhere to the specified format.
# 34206.json does not adhere to the specified format.
# 23076.json does not adhere to the specified format.
# 25182.json does not adhere to the specified format.
# 13665.json does not adhere to the specified format.
# 26900.json does not adhere to the specified format.
# 27714.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/28537.json: Expecting value: line 1 column 1 (char 0)
# 28537.json does not adhere to the specified format.
# 30980.json does not adhere to the specified format.
# 28671.json does not adhere to the specified format.
# 6377.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/4677.json: Expecting value: line 1 column 1 (char 0)
# 4677.json does not adhere to the specified format.
# 9339.json does not adhere to the specified format.
# 4318.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/21547.json: Expecting ':' delimiter: line 29 column 136 (char 1104)
# 21547.json does not adhere to the specified format.
# 19906.json does not adhere to the specified format.
# 28572.json does not adhere to the specified format.
# 24976.json does not adhere to the specified format.
# 16976.json does not adhere to the specified format.
# 29769.json does not adhere to the specified format.
# 32442.json does not adhere to the specified format.
# 34258.json does not adhere to the specified format.
# 15862.json does not adhere to the specified format.
# 29695.json does not adhere to the specified format.
# 14648.json does not adhere to the specified format.
# 13360.json does not adhere to the specified format.
# 25009.json does not adhere to the specified format.
# 11469.json does not adhere to the specified format.
# 11255.json does not adhere to the specified format.
# 5420.json does not adhere to the specified format.
# 32696.json does not adhere to the specified format.
# 7047.json does not adhere to the specified format.
# 24256.json does not adhere to the specified format.
# 20966.json does not adhere to the specified format.
# 38827.json does not adhere to the specified format.
# 21977.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/33303.json: Expecting value: line 1 column 1 (char 0)
# 33303.json does not adhere to the specified format.
# 34696.json does not adhere to the specified format.
# 28854.json does not adhere to the specified format.
# 28126.json does not adhere to the specified format.
# 22208.json does not adhere to the specified format.
# 18865.json does not adhere to the specified format.
# 29701.json does not adhere to the specified format.
# 16703.json does not adhere to the specified format.
# 21305.json does not adhere to the specified format.
# 18434.json does not adhere to the specified format.
# 4199.json does not adhere to the specified format.
# 32623.json does not adhere to the specified format.
# Error decoding JSON in leaflet_jsons/25048.json: Expecting ',' delimiter: line 41 column 8 (char 1192)
# 25048.json does not adhere to the specified format.
# 10464.json does not adhere to the specified format.
# 31721.json does not adhere to the specified format.
# 32471.json does not adhere to the specified format.
# 24249.json does not adhere to the specified format.
# Moved 322 files to the faulty directory.
